# %%
age=30
if age>=18:
    print("Eligible to vote")
else:
    print("Not eligible")
# Out:
# Eligible to vote

# %%
age=17
if age>=18:
    print("Eligible to vote")
else:
    print("Not eligible")
# Out:
# Not eligible

# %%
marks=92
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=60:
    print("Grade C")
else:
    print("Grade D")
# Out:
# Grade A

# %%
marks=50
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=60:
    print("Grade C")
else:
    print("Grade D")
# Out:
# Grade D

# %%
num=int(input("Enter a Number"))
if num%2==0:
   print("Number is even")
else:
   print("Number is odd")
# Out:
# Enter a Number23
# Number is odd

# %%
num=int(input("Enter a Number"))
if num%2==0:
   print("Number is even")
else:
   print("Number is odd")
# Out:
# Enter a Number44
# Number is even

# %%
a=int(input("Enter number a"))
b=int(input("Enter number b"))
c=int(input("Enter number c"))
if a>b:
    print("A is greater")
elif b>c:
    print("B is greater")
else :
    print("C is greater")
# Out:
# Enter number a2
# Enter number b5
# Enter number c8
# C is greater

# %%
age=25
citizen=True
if age>=18:
    if citizen:
        print("Eligible to vote")
else:
    print("Not eligible")
# Out:
# Eligible to vote

# %%
age=15
citizen=True
if age>=18:
    if citizen:
        print("Eligible to vote")
else:
    print("Not eligible")
# Out:
# Not eligible

# %%
age=25
if age>=18 and age<=65:
    print("Working age")
else:
    print("Not working age")
# Out:
# Working age

# %%
age=92
if age>=18 and age<=65:
    print("Working age")
else:
    print("Not working age")
# Out:
# Not working age

# %%
marks=35
if marks>=40 or marks==35:
    print("Eligible for gracing marks")
else:
    print("Not eligible")
# Out:
# Eligible for gracing marks

# %%
marks=20
if marks>=40 or marks==35:
    print("Eligible for gracing marks")
else:
    print("Not eligible")
# Out:
# Not eligible

# %%
is_holiday=True
if not is_holiday:
    print("Go to office")
else:
    print("Go to home")
# Out:
# Go to home

# %%
is_holiday=False
if not is_holiday:
    print("Go to office")
else:
    print("Go to home")
# Out:
# Go to office

# %%
age=25
status="adult" if age>=18 else "minor"
print(status)
# Out:
# adult

# %%
year=int(input("Enter a year"))
status="leap year" if year%4==0 else "not a leap year"
print(status)
# Out:
# Enter a year2016
# leap year

# %%
salary=60000
experience=4
if salary>=50000 and experience>=3:
    print("Eligible for promotion")
else:
    print("Not eligible")
# Out:
# Eligible for promotion
